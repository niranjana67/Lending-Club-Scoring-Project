# %%
# %sql
use catalog lendingclub;
create schema if not exists bronze;
use schema bronze;
select current_catalog(), current_schema();

# %%
loans_repayment_df = spark.read.csv('/Volumes/lendingclub/storagelocation/landing/LoanRepayment/', header = True, inferSchema = True)

# %%
loans_repayment_df.printSchema()

# %%
#Schema enforcement and renaming of columns

payment_schema = '''loan_id string, total_rec_principal float, total_rec_interest float, total_rec_late_fee float, total_payment float,
last_payment_amount float,last_payment_date string, next_payment_date string'''

# %%
loans_repayment_df = spark.read\
.format('csv')\
.option('header', True)\
.schema(payment_schema)\
.load('/Volumes/lendingclub/storagelocation/landing/LoanRepayment/')

# %%
loans_repayment_df.printSchema()

# %%
dbutils.fs.rm("/Volumes/lendingclub/storagelocation/raw/LoanRepayment/", recurse=True)

# %%
loans_repayment_df.write.format('delta').mode('overwrite').save('/Volumes/lendingclub/storagelocation/raw/LoanRepayment/')

# %%
# %sql
create or replace table bronze.LoanRepayment
as
select * 
from delta.`/Volumes/lendingclub/storagelocation/raw/LoanRepayment/`

# %%
# %sql
select * from bronze.LoanRepayment limit 2
