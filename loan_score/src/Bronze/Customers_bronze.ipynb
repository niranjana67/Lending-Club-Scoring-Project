# %%
# %sql
use catalog lendingclub;
create schema if not exists bronze;
use schema bronze;
select current_catalog(), current_schema();

# %%
customer_raw_df = spark.read.csv('/Volumes/lendingclub/storagelocation/landing/Customers/', header = True, inferSchema = True)

# %%
customer_raw_df.printSchema()

# %%
#Schema Enforcement and column rename few columns

customers_schema = '''member_id string, emp_title string, employment_length string, home_ownership string, annual_income float, address_state string, zip_code string, country string, grade string, 
sub_grade string, verification_status string, total_high_credit_limit float, application_type string,annual_income_joint float, verification_status_joint string '''

# %%
customer_raw_df = spark.read.csv('/Volumes/lendingclub/storagelocation/landing/Customers/', header = True, schema = customers_schema)

# %%
customer_raw_df.printSchema()

# %%
dbutils.fs.rm("/Volumes/lendingclub/storagelocation/raw/Customer/", recurse=True)

# %%
customer_raw_df.write.format('delta').mode('overwrite').save('/Volumes/lendingclub/storagelocation/raw/Customer/')

# %%
# %sql
create or replace table bronze.customers
as
select * 
from delta.`/Volumes/lendingclub/storagelocation/raw/Customer/`

# %%
# %sql
select * from bronze.customers limit 2;
