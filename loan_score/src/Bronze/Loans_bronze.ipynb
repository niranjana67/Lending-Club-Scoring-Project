# %%
# %sql
use catalog lendingclub;
create schema if not exists bronze;
use schema bronze;
select current_catalog(), current_schema();

# %%
loans_raw_df = spark.read.csv('/Volumes/lendingclub/storagelocation/landing/Loans/', header = True, inferSchema = True)

# %%
loans_raw_df.printSchema()

# %%
#schema Enforcement and renaming
loans_schema = '''loan_id string, member_id string, Loan_amount float, funded_amount float, loan_term string, int_rate float, installment float,
issue_date string, loan_status string, loan_purpose string, title string'''

# %%
#loans_raw_df = spark.read.csv('project/lendingclub/raw/loans_data_csv', header=True, schema = loans_schema)

loans_raw_df = spark.read \
.format('csv') \
.option('header', True) \
.schema(loans_schema) \
.load('/Volumes/lendingclub/storagelocation/landing/Loans/')

# %%
loans_raw_df.printSchema()

# %%
dbutils.fs.rm("/Volumes/lendingclub/storagelocation/raw/Loans/", recurse=True)

# %%
loans_raw_df.write.format('delta').mode('overwrite').save('/Volumes/lendingclub/storagelocation/raw/Loans/')

# %%
# %sql
create or replace table bronze.loans
as
select * 
from delta.`/Volumes/lendingclub/storagelocation/raw/Loans/`

# %%
# %sql
select * from bronze.loans limit 2;
